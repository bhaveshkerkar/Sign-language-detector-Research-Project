# %%
import pandas as pd

# %%
df = pd.read_csv("asl_landmarks.csv")
print("Total samples: ", len(df))
df.head()
# Out:
# Total samples:  2497
#   label        x0        y0            z0        x1        y1        z1  \
# 0     A  0.593800  0.798356 -7.649077e-07  0.503934  0.740276 -0.019193
# 1     A  0.730166  0.617582 -5.512676e-07  0.639415  0.565125 -0.029493
# 2     A  0.427747  0.586118 -8.728184e-07  0.332063  0.539541 -0.013546
# 3     A  0.468265  0.601081 -8.472105e-07  0.369813  0.546696 -0.006734
# 4     A  0.528097  0.625915 -7.491166e-07  0.433816  0.579672 -0.020089
#
#          x2        y2        z2  ...       z17       x18       y18       z18  \
# 0  0.444183  0.631012 -0.027275  ... -0.028513  0.618038  0.509346 -0.051375
# 1  0.577366  0.462825 -0.037581  ... -0.006989  0.769189  0.340501 -0.034803
# 2  0.258781  0.429579 -0.019302  ... -0.032051  0.426942  0.266215 -0.055565
# 3  0.302968  0.442877 -0.009222  ... -0.030330  0.476178  0.295535 -0.046805
# 4  0.362457  0.470722 -0.027540  ... -0.027452  0.545174  0.317821 -0.050836
#
#         x19       y19       z19       x20       y20       z20
# 0  0.605658  0.579815 -0.035927  0.605530  0.627095 -0.015392
# 1  0.759857  0.405193 -0.023299  0.747320  0.447488 -0.003749
# 2  0.421107  0.343477 -0.038379  0.433551  0.399313 -0.016079
# 3  0.467783  0.366750 -0.029050  0.475853  0.420130 -0.009718
# 4  0.536625  0.386965 -0.036382  0.537917  0.441104 -0.017064
#
# [5 rows x 64 columns]

# %%
X = df.drop(["label"], axis = 1).values
y = df["label"].values

print("X shape: ", X.shape)
print("y shape: ", y.shape)
# Out:
# X shape:  (2497, 63)
# y shape:  (2497,)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

le = LabelEncoder()
y_encoded = le.fit_transform(y)

print("Label Mapping: ", dict(zip(le.classes_, le.transform(le.classes_))))
# Out:
# Label Mapping:  {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4}

# %%
X_train, X_test, y_train, y_test = train_test_split(
  X, y_encoded, test_size = 0.2, random_state = 42, shuffle=True
)

print("Training samples: ", X_train.shape)
print("Testing samples: ", X_test.shape)
# Out:
# Training samples:  (1997, 63)
# Testing samples:  (500, 63)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

model = Sequential([
  Dense(256, activation='relu', input_shape=(63,)),
  Dropout(0.3),

  Dense(128, activation='relu'),
  Dropout(0.3),

  Dense(64, activation='relu'),

  Dense(5, activation='softmax')
])

# %%
model.compile(
  optimizer = Adam(learning_rate=0.001),
  loss = 'sparse_categorical_crossentropy',
  metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               16384
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 57,861
# Trainable params: 57,861
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
  X_train, y_train,
  validation_data = (X_test, y_test),
  epochs = 50,
  batch_size = 32
)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 1s 6ms/step - loss: 1.4606 - accuracy: 0.3726 - val_loss: 1.1919 - val_accuracy: 0.6400
# Epoch 2/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.9428 - accuracy: 0.6885 - val_loss: 0.5107 - val_accuracy: 0.8800
# Epoch 3/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.3928 - accuracy: 0.8958 - val_loss: 0.1670 - val_accuracy: 0.9540
# Epoch 4/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1918 - accuracy: 0.9424 - val_loss: 0.0964 - val_accuracy: 0.9880
# Epoch 5/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1048 - accuracy: 0.9700 - val_loss: 0.0421 - val_accuracy: 0.9960
# Epoch 6/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0687 - accuracy: 0.9820 - val_loss: 0.0293 - val_accuracy: 0.9920
# Epoch 7/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0618 - accuracy: 0.9815 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 8/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0371 - accuracy: 0.9940 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 9/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0328 - accuracy: 0.9940 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 10/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0365 - accuracy: 0.9890 - val_loss: 0.0306 - val_accuracy: 0.9880
# Epoch 11/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 0.9925 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 12/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 0.9985 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 13/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0247 - accuracy: 0.9930 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 14/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.9955 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 15/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0332 - accuracy: 0.9900 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 16/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.9935 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 17/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0282 - accuracy: 0.9910 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 18/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 0.9885 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 19/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0239 - accuracy: 0.9915 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 20/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 21/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 0.9890 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 22/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 0.9965 - val_loss: 8.9540e-04 - val_accuracy: 1.0000
# Epoch 23/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 7.0910e-04 - val_accuracy: 1.0000
# Epoch 24/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 0.9945 - val_loss: 0.0171 - val_accuracy: 0.9940
# Epoch 25/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 0.9940 - val_loss: 5.0051e-04 - val_accuracy: 1.0000
# Epoch 26/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 27/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 3.1728e-04 - val_accuracy: 1.0000
# Epoch 28/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 2.2363e-04 - val_accuracy: 1.0000
# Epoch 29/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 0.0543 - val_accuracy: 0.9720
# Epoch 30/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0357 - accuracy: 0.9910 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 31/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 0.9975 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 32/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 0.9940 - val_loss: 0.0664 - val_accuracy: 0.9720
# Epoch 33/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0285 - accuracy: 0.9935 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 34/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9955 - val_loss: 7.2118e-04 - val_accuracy: 1.0000
# Epoch 35/50
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.0042 - val_accuracy: 0.9980
# Epoch 36/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 0.9965 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 37/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 0.9960 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 38/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 0.9965 - val_loss: 0.0067 - val_accuracy: 0.9980
# Epoch 39/50
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9945 - val_loss: 9.4687e-04 - val_accuracy: 1.0000
# Epoch 40/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0462 - accuracy: 0.9800 - val_loss: 0.0221 - val_accuracy: 0.9920
# Epoch 41/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 42/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 0.9965 - val_loss: 0.0033 - val_accuracy: 0.9980
# Epoch 43/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 0.9965 - val_loss: 3.0295e-04 - val_accuracy: 1.0000
# Epoch 44/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.9915 - val_loss: 4.4350e-04 - val_accuracy: 1.0000
# Epoch 45/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 0.9990 - val_loss: 5.9894e-04 - val_accuracy: 1.0000
# Epoch 46/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9965 - val_loss: 3.1289e-04 - val_accuracy: 1.0000
# Epoch 47/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 7.2476e-05 - val_accuracy: 1.0000
# Epoch 48/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.2205e-05 - val_accuracy: 1.0000
# Epoch 49/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.0061 - val_accuracy: 0.9980
# Epoch 50/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 0.9915 - val_loss: 0.0083 - val_accuracy: 0.9960

# %%
# save trained model
model.save("asl_landmark_anne.h5")
print("model saved!")
# Out:
# model saved!

# %%
# save label encoder
import pickle
with open("label_encoder.pkl", "wb") as f:
  pickle.dump(le, f)

print("label encoder saved!")
# Out:
# label encoder saved!

# %%
import cv2
import mediapipe as mp
import tensorflow as tf
import numpy as np
import sklearn
import pandas as pd

print("OpenCV:", cv2.__version__)
print("MediaPipe:", mp.__version__)
print("TensorFlow:", tf.__version__)
print("NumPy:", np.__version__)
print("Scikit-learn:", sklearn.__version__)
print("Pandas:", pd.__version__)

mpHands = mp.solutions.hands
print("Hands module loaded successfully ✅")
# Out:
# OpenCV: 4.8.1
# MediaPipe: 0.10.8
# TensorFlow: 2.12.0
# NumPy: 1.23.5
# Scikit-learn: 1.3.2
# Pandas: 2.1.4
# Hands module loaded successfully ✅

# %%
# install below versions
# OpenCV: 4.8.1
# MediaPipe: 0.10.8
# TensorFlow: 2.12.0
# NumPy: 1.23.5
# Scikit-learn: 1.3.2
# Pandas: 2.1.4
