# %%
import pandas as pd

# %%
df = pd.read_csv("asl_landmarks.csv")
print("Total samples: ", len(df))
df.head()
# Out:
# Total samples:  5427
#   label        x0        y0            z0        x1        y1        z1  \
# 0     A  0.593800  0.798356 -7.649077e-07  0.503934  0.740276 -0.019193
# 1     A  0.730166  0.617582 -5.512676e-07  0.639415  0.565125 -0.029493
# 2     A  0.427747  0.586118 -8.728184e-07  0.332063  0.539541 -0.013546
# 3     A  0.468265  0.601081 -8.472105e-07  0.369813  0.546696 -0.006734
# 4     A  0.528097  0.625915 -7.491166e-07  0.433816  0.579672 -0.020089
#
#          x2        y2        z2  ...       z17       x18       y18       z18  \
# 0  0.444183  0.631012 -0.027275  ... -0.028513  0.618038  0.509346 -0.051375
# 1  0.577366  0.462825 -0.037581  ... -0.006989  0.769189  0.340501 -0.034803
# 2  0.258781  0.429579 -0.019302  ... -0.032051  0.426942  0.266215 -0.055565
# 3  0.302968  0.442877 -0.009222  ... -0.030330  0.476178  0.295535 -0.046805
# 4  0.362457  0.470722 -0.027540  ... -0.027452  0.545174  0.317821 -0.050836
#
#         x19       y19       z19       x20       y20       z20
# 0  0.605658  0.579815 -0.035927  0.605530  0.627095 -0.015392
# 1  0.759857  0.405193 -0.023299  0.747320  0.447488 -0.003749
# 2  0.421107  0.343477 -0.038379  0.433551  0.399313 -0.016079
# 3  0.467783  0.366750 -0.029050  0.475853  0.420130 -0.009718
# 4  0.536625  0.386965 -0.036382  0.537917  0.441104 -0.017064
#
# [5 rows x 64 columns]

# %%
X = df.drop(["label"], axis = 1).values
y = df["label"].values

print("X shape: ", X.shape)
print("y shape: ", y.shape)
# Out:
# X shape:  (5427, 63)
# y shape:  (5427,)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

le = LabelEncoder()
y_encoded = le.fit_transform(y)

print("Label Mapping: ", dict(zip(le.classes_, le.transform(le.classes_))))
# Out:
# Label Mapping:  {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8}

# %%
X_train, X_test, y_train, y_test = train_test_split(
  X, y_encoded, test_size = 0.2, random_state = 42, shuffle=True
)

print("Training samples: ", X_train.shape)
print("Testing samples: ", X_test.shape)
# Out:
# Training samples:  (4341, 63)
# Testing samples:  (1086, 63)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

model = Sequential([
  Dense(256, activation='relu', input_shape=(63,)),
  Dropout(0.3),

  Dense(128, activation='relu'),
  Dropout(0.3),

  Dense(64, activation='relu'),

  Dense(9, activation='softmax')
])

# %%
model.compile(
  optimizer = Adam(learning_rate=0.001),
  loss = 'sparse_categorical_crossentropy',
  metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 256)               16384
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_14 (Dense)            (None, 64)                8256
#
#  dense_15 (Dense)            (None, 9)                 585
#
# =================================================================
# Total params: 58,121
# Trainable params: 58,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
  X_train, y_train,
  validation_data = (X_test, y_test),
  epochs = 50,
  batch_size = 32
)
# Out:
# Epoch 1/50
# 136/136 [==============================] - 2s 8ms/step - loss: 1.8167 - accuracy: 0.3181 - val_loss: 1.2190 - val_accuracy: 0.5221
# Epoch 2/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8504 - accuracy: 0.7097 - val_loss: 0.3666 - val_accuracy: 0.9273
# Epoch 3/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.3371 - accuracy: 0.9042 - val_loss: 0.1285 - val_accuracy: 0.9825
# Epoch 4/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.1539 - accuracy: 0.9601 - val_loss: 0.0358 - val_accuracy: 0.9945
# Epoch 5/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0922 - accuracy: 0.9770 - val_loss: 0.0260 - val_accuracy: 0.9963
# Epoch 6/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0797 - accuracy: 0.9774 - val_loss: 0.0288 - val_accuracy: 0.9972
# Epoch 7/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0601 - accuracy: 0.9855 - val_loss: 0.0137 - val_accuracy: 0.9963
# Epoch 8/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0495 - accuracy: 0.9857 - val_loss: 0.0177 - val_accuracy: 0.9936
# Epoch 9/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0395 - accuracy: 0.9887 - val_loss: 0.0175 - val_accuracy: 0.9936
# Epoch 10/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0491 - accuracy: 0.9862 - val_loss: 0.0254 - val_accuracy: 0.9954
# Epoch 11/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0461 - accuracy: 0.9855 - val_loss: 0.0055 - val_accuracy: 0.9982
# Epoch 12/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0263 - accuracy: 0.9929 - val_loss: 0.0115 - val_accuracy: 0.9982
# Epoch 13/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0262 - accuracy: 0.9926 - val_loss: 0.0056 - val_accuracy: 0.9991
# Epoch 14/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0529 - accuracy: 0.9816 - val_loss: 0.0070 - val_accuracy: 0.9972
# Epoch 15/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0329 - accuracy: 0.9885 - val_loss: 0.0204 - val_accuracy: 0.9954
# Epoch 16/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0458 - accuracy: 0.9853 - val_loss: 0.0142 - val_accuracy: 0.9945
# Epoch 17/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0265 - accuracy: 0.9935 - val_loss: 0.0031 - val_accuracy: 0.9982
# Epoch 18/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0301 - accuracy: 0.9885 - val_loss: 0.0382 - val_accuracy: 0.9899
# Epoch 19/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0274 - accuracy: 0.9929 - val_loss: 0.0036 - val_accuracy: 0.9991
# Epoch 20/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0248 - accuracy: 0.9940 - val_loss: 0.0059 - val_accuracy: 0.9982
# Epoch 21/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0245 - accuracy: 0.9931 - val_loss: 0.0031 - val_accuracy: 0.9982
# Epoch 22/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0462 - accuracy: 0.9873 - val_loss: 0.0039 - val_accuracy: 0.9991
# Epoch 23/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0236 - accuracy: 0.9926 - val_loss: 0.0091 - val_accuracy: 0.9972
# Epoch 24/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0399 - accuracy: 0.9866 - val_loss: 0.0079 - val_accuracy: 0.9982
# Epoch 25/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0328 - accuracy: 0.9901 - val_loss: 0.0051 - val_accuracy: 0.9991
# Epoch 26/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0211 - accuracy: 0.9942 - val_loss: 0.0025 - val_accuracy: 0.9991
# Epoch 27/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0813 - accuracy: 0.9724 - val_loss: 0.0282 - val_accuracy: 0.9926
# Epoch 28/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0257 - accuracy: 0.9917 - val_loss: 0.0045 - val_accuracy: 0.9991
# Epoch 29/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0141 - accuracy: 0.9965 - val_loss: 0.0023 - val_accuracy: 0.9991
# Epoch 30/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0163 - accuracy: 0.9959 - val_loss: 0.0053 - val_accuracy: 0.9991
# Epoch 31/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0301 - accuracy: 0.9915 - val_loss: 0.0070 - val_accuracy: 0.9972
# Epoch 32/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0235 - accuracy: 0.9940 - val_loss: 0.0025 - val_accuracy: 0.9991
# Epoch 33/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0210 - accuracy: 0.9933 - val_loss: 0.0020 - val_accuracy: 0.9991
# Epoch 34/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0191 - accuracy: 0.9947 - val_loss: 0.0025 - val_accuracy: 0.9991
# Epoch 35/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0221 - accuracy: 0.9926 - val_loss: 0.0051 - val_accuracy: 0.9991
# Epoch 36/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0207 - accuracy: 0.9933 - val_loss: 0.0056 - val_accuracy: 0.9991
# Epoch 37/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0391 - accuracy: 0.9857 - val_loss: 0.0036 - val_accuracy: 0.9982
# Epoch 38/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0301 - accuracy: 0.9887 - val_loss: 0.0057 - val_accuracy: 0.9972
# Epoch 39/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0308 - accuracy: 0.9910 - val_loss: 0.0079 - val_accuracy: 0.9963
# Epoch 40/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0249 - accuracy: 0.9926 - val_loss: 0.0026 - val_accuracy: 0.9991
# Epoch 41/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0166 - accuracy: 0.9952 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 42/50
# 136/136 [==============================] - 1s 6ms/step - loss: 0.0290 - accuracy: 0.9899 - val_loss: 0.0030 - val_accuracy: 0.9991
# Epoch 43/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0233 - accuracy: 0.9933 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 44/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0276 - accuracy: 0.9915 - val_loss: 0.0050 - val_accuracy: 0.9991
# Epoch 45/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0313 - accuracy: 0.9901 - val_loss: 0.0224 - val_accuracy: 0.9926
# Epoch 46/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0247 - accuracy: 0.9917 - val_loss: 0.0018 - val_accuracy: 0.9991
# Epoch 47/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0167 - accuracy: 0.9949 - val_loss: 0.0038 - val_accuracy: 0.9972
# Epoch 48/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0294 - accuracy: 0.9908 - val_loss: 0.0036 - val_accuracy: 0.9982
# Epoch 49/50
# 136/136 [==============================] - 1s 4ms/step - loss: 0.0258 - accuracy: 0.9908 - val_loss: 0.0084 - val_accuracy: 0.9972
# Epoch 50/50
# 136/136 [==============================] - 1s 5ms/step - loss: 0.0162 - accuracy: 0.9952 - val_loss: 0.0017 - val_accuracy: 1.0000

# %%
# save trained model
model.save("asl_landmark_anni.h5")
print("model saved!")
# Out:
# model saved!

# %%
# save label encoder
import pickle
with open("label_encoder.pkl", "wb") as f:
  pickle.dump(le, f)

print("label encoder saved!")
# Out:
# label encoder saved!

# %%
import cv2
import mediapipe as mp
import tensorflow as tf
import numpy as np
import sklearn
import pandas as pd

print("OpenCV:", cv2.__version__)
print("MediaPipe:", mp.__version__)
print("TensorFlow:", tf.__version__)
print("NumPy:", np.__version__)
print("Scikit-learn:", sklearn.__version__)
print("Pandas:", pd.__version__)

mpHands = mp.solutions.hands
print("Hands module loaded successfully ✅")
# Out:
# OpenCV: 4.8.1
# MediaPipe: 0.10.8
# TensorFlow: 2.12.0
# NumPy: 1.23.5
# Scikit-learn: 1.3.2
# Pandas: 2.1.4
# Hands module loaded successfully ✅

# %%
# install below versions
# OpenCV: 4.8.1
# MediaPipe: 0.10.8
# TensorFlow: 2.12.0
# NumPy: 1.23.5
# Scikit-learn: 1.3.2
# Pandas: 2.1.4
